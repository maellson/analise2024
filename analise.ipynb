# %%
import streamlit as st
import pandas as pd
import plotly.express as px

# %%
st.set_page_config(layout='wide')

# %%
df = pd.read_csv("relatrorio2024.csv",sep=";", decimal=".", encoding="cp1252", dtype={34: str})

df.head()
# Out:
#   Aliquota  Matrícula                          Logradouro    Bairro  \
# 0     1,50   10000402     AVN - PROFESSOR ALMEIDA BARRETO  SAO JOSE
# 1     1,00   10004416            RUA - JOSE DO PATROCINIO  SAO JOSE
# 2     1,00   10004742            RUA - JOSE DO PATROCINIO  SAO JOSE
# 3     1,00   10008101  RUA - CAPITAO JOSE AMANCIO BARBOSA  SAO JOSE
# 4     1,50   10008667             RUA - DOUTOR JOAO MOURA  SAO JOSE
#
#                   situacao  Unidade  area_edif_lote condominio conservacao  \
# 0         UMA FRENTE - 1,0        1          795.00         {}  30-REGULAR
# 1         UMA FRENTE - 1,0        1          231.00         {}  30-REGULAR
# 2         UMA FRENTE - 1,0        1           70.19         {}      22-BOM
# 3         UMA FRENTE - 1,0       29         5069.60         {}      22-BOM
# 4  ESQUINA/+1 FRENTE - 1,0        4          637.42         {}    14-OTIMO
#
#   dt_cad_edif  ... quadra             tipo_construcao  tipo_imovel vlr_iptu  \
# ...
